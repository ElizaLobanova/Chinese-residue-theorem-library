# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
with open('time16shortData.csv', 'r') as f:
    lines = f.readlines()
    
    gmp_time = []
    crt_time = []
    data_size = []
    lunch_times = []
    for line in lines:
        gmp_time.append(float(line.split(' ')[0]))
        crt_time.append(float(line.split(' ')[1]))
        data_size.append(float(line.split(' ')[2]))
        lunch_times.append(float(line.split(' ')[3]))
    gmp_time = np.array(gmp_time)
    crt_time = np.array(crt_time)
    data_size = np.array(data_size)
    lunch_times = np.array(lunch_times)
    print(gmp_time, crt_time, data_size, lunch_times)
    add_p_ms_gmp = (data_size * lunch_times) / gmp_time
    add_p_ms_crt = (data_size * lunch_times) / crt_time
    plt.xlabel('размер данных', fontsize=16)
    plt.ylabel('сложения / мс', fontsize=16)
    plt.scatter(data_size, add_p_ms_gmp, color='red', label='GMP')
    plt.scatter(data_size, add_p_ms_crt, color='green', label='CRT')
    plt.legend(loc='upper left')
    plt.xscale('log')
    plt.yscale('log')
    #plt.savefig('../../time.pdf')
    plt.show()
# Out:
# [35301.8 36540.9 36869.  35424.4 36084.  35078.  35185.3 35488.6 35780.2
#  35406.1 35090.9 35128.7 35009.  35382.  35056.3 34315.8] [5.90292e+01 1.83785e+01 5.49600e+01 1.24661e+02 2.05184e+02 5.43814e+02
#  9.11995e+02 1.95378e+03 3.41224e+03 6.03160e+03 1.29132e+04 2.19278e+04
#  3.47935e+04 7.38709e+04 2.36544e+05 3.60683e+05] [1.0000e+06 5.0000e+05 2.5000e+05 1.2500e+05 6.2500e+04 3.1250e+04
#  1.5625e+04 7.8120e+03 3.9060e+03 1.9530e+03 9.7600e+02 4.8800e+02
#  2.4400e+02 1.2200e+02 6.1000e+01 3.0000e+01] [1.0000e+03 2.0000e+03 4.0000e+03 8.0000e+03 1.6000e+04 3.2000e+04
#  6.4000e+04 1.2800e+05 2.5600e+05 5.1200e+05 1.0240e+06 2.0480e+06
#  4.0960e+06 8.1920e+06 1.6384e+07 3.2768e+07]
