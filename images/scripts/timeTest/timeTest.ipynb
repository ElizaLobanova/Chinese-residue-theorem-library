# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
with open('time12.csv', 'r') as f:
    lines = f.readlines()
    
    gmp_time = []
    crt_time = []
    data_size = []
    lunch_times = []
    for line in lines:
        gmp_time.append(float(line.split(' ')[0]))
        crt_time.append(float(line.split(' ')[1]))
        data_size.append(float(line.split(' ')[2]))
        lunch_times.append(float(line.split(' ')[3]))
    gmp_time = np.array(gmp_time)
    crt_time = np.array(crt_time)
    data_size = np.array(data_size)
    lunch_times = np.array(lunch_times)
    print(gmp_time, crt_time, data_size, lunch_times)
    add_p_ms_gmp = (data_size * lunch_times) / gmp_time
    add_p_ms_crt = (data_size * lunch_times) / crt_time
    plt.xlabel('размер данных', fontsize=16)
    plt.ylabel('сложения / мс', fontsize=16)
    plt.scatter(data_size, add_p_ms_gmp, color='red', label='GMP')
    plt.scatter(data_size, add_p_ms_crt, color='green', label='CRT')
    plt.legend(loc='upper left')
    plt.xscale('log')
    plt.yscale('log')
    #plt.savefig('../../time.pdf')
    plt.show()
# Out:
# [35316.6 36248.8 36834.7 35352.  35207.6 35109.7 34987.8 34713.1 34856.4
#  34953.8 34242.4 34652.8] [8.13072e+01 2.05262e+00 6.11580e+00 2.44851e+01 1.21470e+02 3.05826e+02
#  2.20041e+03 4.13132e+03 6.62885e+03 2.25586e+04 8.73572e+04 2.22301e+05] [1.000000e+07 3.333333e+06 1.111111e+06 3.703700e+05 1.234560e+05
#  4.115200e+04 1.371700e+04 4.572000e+03 1.524000e+03 5.080000e+02
#  1.690000e+02 5.600000e+01] [1.00000e+02 3.00000e+02 9.00000e+02 2.70000e+03 8.10000e+03 2.43000e+04
#  7.29000e+04 2.18700e+05 6.56100e+05 1.96830e+06 5.90490e+06 1.77147e+07]
