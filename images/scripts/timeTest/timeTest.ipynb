# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
with open('time sequential18.csv', 'r') as f:
    lines = f.readlines()
    
    gmp_time = []
    crt_time = []
    data_size = []
    lunch_times = []
    for line in lines:
        gmp_time.append(float(line.split(' ')[0]))
        crt_time.append(float(line.split(' ')[1]))
        data_size.append(float(line.split(' ')[2]))
        lunch_times.append(float(line.split(' ')[3]))
    gmp_time = np.array(gmp_time)
    crt_time = np.array(crt_time)
    data_size = np.array(data_size)
    lunch_times = np.array(lunch_times)
    print(gmp_time, crt_time, data_size, lunch_times)
    add_p_ms_gmp = (data_size * lunch_times) / gmp_time
    add_p_ms_crt = (data_size * lunch_times) / crt_time
    plt.xlabel('размер данных', fontsize=16)
    plt.ylabel('сложения / мс', fontsize=16)
    plt.scatter(data_size, add_p_ms_gmp, color='red', label='GMP')
    plt.scatter(data_size, add_p_ms_crt, color='green', label='КТО')
    plt.legend(loc='lower right')
    plt.xscale('log')
    plt.yscale('log')
    plt.savefig('../../time_sequential18.pdf')
    plt.show()
# Out:
# [35574.7 35734.5 35234.9 35122.4 35101.5 35150.4 35053.6 35220.9 35075.9
#  35588.1 35374.1 35270.1 34940.4 35228.1 35982.2 35792.4 35406.5 35550.3] [975942.  691433.  452731.  328714.  244669.  235271.  228472.  224786.
#  223097.  222363.  221486.  218554.  213685.  203941.  185198.  149538.
#  112635.   75713.9] [1.00000e+01 2.00000e+01 4.00000e+01 8.00000e+01 1.60000e+02 3.20000e+02
#  6.40000e+02 1.28000e+03 2.56000e+03 5.12000e+03 1.02400e+04 2.04800e+04
#  4.09600e+04 8.19200e+04 1.63840e+05 3.27680e+05 6.55360e+05 1.31072e+06] [1.00000e+08 5.00000e+07 2.50000e+07 1.25000e+07 6.25000e+06 3.12500e+06
#  1.56250e+06 7.81250e+05 3.90625e+05 1.95312e+05 9.76560e+04 4.88280e+04
#  2.44140e+04 1.22070e+04 6.10300e+03 3.05100e+03 1.52500e+03 7.62000e+02]
